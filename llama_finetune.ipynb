# %%
# !pip install seaborn
# !pip install trl
# !pip install unsloth
# !pip install --upgrade numpy
# Out:
# ...
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.9
#     Uninstalling dill-0.3.9:
#       Successfully uninstalled dill-0.3.9
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.21.0
#     Uninstalling accelerate-0.21.0:
#       Successfully uninstalled accelerate-0.21.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.2.1
#     Uninstalling datasets-2.2.1:
#       Successfully uninstalled datasets-2.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.1.1 requires nvidia-ml-py3==7.352.0, which is not installed.
# autogluon-multimodal 1.1.1 requires accelerate<0.22.0,>=0.21.0, but you have accelerate 1.2.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires jsonschema<4.22,>=4.18, but you have jsonschema 4.23.0 which is incompatible.
# ...

# %%
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# Found existing installation: unsloth 2024.12.4
# Uninstalling unsloth-2024.12.4:
#   Successfully uninstalled unsloth-2024.12.4
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-jtu5oqy5/unsloth_558c8b01e8354fa284cb8fbdf3d01f99
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-jtu5oqy5/unsloth_558c8b01e8354fa284cb8fbdf3d01f99
#   Resolved https://github.com/unslothai/unsloth.git to commit df808d074d307d396b8c04640ef51375d68f2ef0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for unsloth: filename=unsloth-2024.12.4-py3-none-any.whl size=173562 sha256=76a0cb47d939558bae1ce0a83f369217be9601c54ae0418dd60b113547abada7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g0bm722l/wheels/d1/17/05/850ab10c33284a4763b0595cd8ea9d01fce6e221cac24b3c01
# Successfully built unsloth
# ...

# %%
# !pip cache purge
# !pip install --force-reinstall torchvision
# Out:
# Files removed: 568
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 89.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 35.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 81.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.3 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 52.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 72.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 95.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 79.8 MB/s eta 0:00:0000:0100:01
# ...

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import torch
from trl import SFTTrainer
from transformers import TrainingArguments, TextStreamer
from unsloth.chat_templates import get_chat_template
from unsloth import FastLanguageModel
from datasets import Dataset
from unsloth import is_bfloat16_supported

# Saving model
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Warnings
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
# !pip install torch==2.1.1 torchvision==0.15.2
# !pip install --upgrade transformers==4.34.0 trl==0.15.0
# Out:
# ...
#   Using cached torch-2.1.1-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# ...
#   Using cached torchvision-0.15.2-cp311-cp311-manylinux1_x86_64.whl.metadata (11 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
pip install --upgrade transformers datasets trl accelerate
# Out:
# ...
#   Using cached transformers-4.47.0-py3-none-any.whl.metadata (43 kB)
# ...
#   Using cached tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import subprocess

# Uninstall TensorFlow and automatically confirm the prompt
subprocess.run(['pip', 'uninstall', '-y', 'tensorflow'])
# Out:
# Found existing installation: tensorflow 2.14.0
# Uninstalling tensorflow-2.14.0:
#   Successfully uninstalled tensorflow-2.14.0
# CompletedProcess(args=['pip', 'uninstall', '-y', 'tensorflow'], returncode=0)

# %%
import boto3
import pandas as pd
from io import BytesIO

# Initialize the S3 client
s3 = boto3.client('s3')

# List objects in your bucket to verify access
bucket_name = "biascheck-232442840523-us-east-1"
response = s3.list_objects_v2(Bucket=bucket_name)

# Print the contents of the bucket
for obj in response.get('Contents', []):
    print(obj['Key'])
# Out:
# distilbert_cls_model.h5
# drive-download-20241009T011832Z-001/bias_test_full.csv
# drive-download-20241009T011832Z-001/bias_test_med.csv
# drive-download-20241009T011832Z-001/bias_test_sm.csv
# drive-download-20241009T011832Z-001/bias_train_full.csv
# drive-download-20241009T011832Z-001/bias_train_med.csv
# drive-download-20241009T011832Z-001/bias_train_sm.csv
# drive-download-20241009T011832Z-001/bias_val_full.csv
# drive-download-20241009T011832Z-001/bias_val_med.csv
# drive-download-20241009T011832Z-001/bias_val_sm.csv
# model-artifacts.tar.gz
# model.tar.gz
# model_weights/
# model_weights/cls_weights.02-0.71.hdf5
# new_model.tar.gz
# src.tar.gz
# src.zip

# %%
s3_data_path_train="drive-download-20241009T011832Z-001/bias_train_sm.csv"

response = s3.get_object(Bucket=bucket_name, Key=s3_data_path_train)
training_data = pd.read_csv(BytesIO(response['Body'].read()))

s3_data_path_val="drive-download-20241009T011832Z-001/bias_val_sm.csv"

response = s3.get_object(Bucket=bucket_name, Key=s3_data_path_val)
validation_data = pd.read_csv(BytesIO(response['Body'].read()))

# %%
max_seq_length = 520
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Llama-3.2-1B-bnb-4bit",
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    dtype=None,
)

model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    lora_alpha=16,
    lora_dropout=0,
    target_modules=["q_proj", "k_proj", "v_proj", "up_proj", "down_proj", "o_proj", "gate_proj"],
    use_rslora=True,
    use_gradient_checkpointing="unsloth",
    random_state = 32,
    loftq_config = None,
)
print(model.print_trainable_parameters())
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2024.12.4 patched 16 layers with 16 QKV layers, 16 O layers and 16 MLP layers.
# trainable params: 11,272,192 || all params: 1,247,086,592 || trainable%: 0.9039
# None

# %%
data_prompt = """Provide a revised version of the input text that removes any subjective elements and ensures neutrality.

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token
def formatting_prompt(examples):
    inputs       = examples["src_raw"]
    outputs      = examples["tgt_raw"]
    texts = []
    for input_, output in zip(inputs, outputs):
        text = data_prompt.format(input_, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# %%
train_data = Dataset.from_pandas(training_data)
train_data = training_data.map(formatting_prompt, batched=True)

val_data = Dataset.from_pandas(validation_data)
val_data = val_data.map(formatting_prompt, batched=True)
# Out:
# Map:   0%|          | 0/3593 [00:00<?, ? examples/s]

# %%
trainer=SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_data,
    eval_dataset=val_data,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    packing=False,
    args=TrainingArguments(
        learning_rate=3e-4,
        lr_scheduler_type="linear",
        per_device_train_batch_size=16,
        gradient_accumulation_steps=8,
        num_train_epochs=40,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        warmup_steps=10,
        output_dir="output",
        seed=0,
    ),
)

trainer.train()
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 703 | Num Epochs = 40
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 8
# \        /    Total batch size = 128 | Total steps = 200
#  "-____-"     Number of trainable parameters = 11,272,192
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 38:21, Epoch 33/40]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>17.537300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>17.311900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>17.462300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>16.655700</td>
# ...

# %%
text="He started writing books revealing a vast world conspiracy."

# %%
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print("Answer of the question is:", answer)
# Out:
# Answer of the question is:
# he wrote books revealing a vast world conspiracy.<|end_of_text|>

# %%
data_prompt = """Provide a revised version of the input text that removes any subjective bias and ensures neutrality, objectivity and an unbiased point of view.

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token
def formatting_prompt(examples):
    inputs       = examples["src_raw"]
    outputs      = examples["tgt_raw"]
    texts = []
    for input_, output in zip(inputs, outputs):
        text = data_prompt.format(input_, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# %%
train_data = Dataset.from_pandas(training_data)
train_data = train_data.map(formatting_prompt, batched=True)

val_data = Dataset.from_pandas(validation_data)
val_data = val_data.map(formatting_prompt, batched=True)
# Out:
# ...
# Map:   0%|          | 0/769 [00:00<?, ? examples/s]

# %%
trainer=SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_data,
    eval_dataset=val_data,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    packing=False,
    args=TrainingArguments(
        learning_rate=3e-4,
        lr_scheduler_type="linear",
        per_device_train_batch_size=16,
        gradient_accumulation_steps=8,
        num_train_epochs=5,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        warmup_steps=10,
        output_dir="output",
        seed=0,
    ),
)

trainer.train()
# Out:
# ...
# Map (num_proc=2):   0%|          | 0/769 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 3,593 | Num Epochs = 5
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 8
# \        /    Total batch size = 128 | Total steps = 140
#  "-____-"     Number of trainable parameters = 11,272,192
#     <div>
#
#       <progress value='140' max='140' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [140/140 11:08, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.104200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.101100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.104500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.100400</td>
# ...

# %%
text="Marriage is a holy union of individuals."

model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print("Answer of the question is:", answer)
# Out:
# Answer of the question is:
# Marriage is a legal union of individuals.<|end_of_text|>

# %%
text="The lyrics are about mankind's perceived idea of hell."

model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print("Answer of the question is:", answer)
# Out:
# Answer of the question is:
# the lyrics are about people's ideas of hell.<|end_of_text|>

# %%
text="Jewish forces overcome Arab militants."

model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print("Answer of the question is:", answer)
# Out:
# Answer of the question is:
# Jewish forces overcome Arab militants.<|end_of_text|>

# %%
text="He started writing books revealing a vast world conspiracy."

model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print("Answer of the question is:", answer)
# Out:
# Answer of the question is:
# he wrote books revealing a vast world conspiracy.<|end_of_text|>

# %%
data_prompt = """Convert from biased to unbiased.

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token
def formatting_prompt(examples):
    inputs       = examples["src_raw"]
    outputs      = examples["tgt_raw"]
    texts = []
    for input_, output in zip(inputs, outputs):
        text = data_prompt.format(input_, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# %%
train_data = Dataset.from_pandas(training_data)
train_data = train_data.map(formatting_prompt, batched=True)

val_data = Dataset.from_pandas(validation_data)
val_data = val_data.map(formatting_prompt, batched=True)
# Out:
# ...
# Map:   0%|          | 0/769 [00:00<?, ? examples/s]

# %%
trainer=SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_data,
    eval_dataset=val_data,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    packing=False,
    args=TrainingArguments(
        learning_rate=3e-4,
        lr_scheduler_type="linear",
        per_device_train_batch_size=16,
        gradient_accumulation_steps=8,
        num_train_epochs=5,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        warmup_steps=10,
        output_dir="output",
        seed=0,
    ),
)

trainer.train()
# Out:
# ...
# Map (num_proc=2):   0%|          | 0/769 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 3,593 | Num Epochs = 5
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 8
# \        /    Total batch size = 128 | Total steps = 140
#  "-____-"     Number of trainable parameters = 11,272,192
#     <div>
#
#       <progress value='140' max='140' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [140/140 07:01, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>6.238400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.721300</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.196800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.570400</td>
# ...

# %%
text="He started writing books revealing a vast world conspiracy."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
# Out:
# he wrote books revealing a vast world conspiracy.<|end_of_text|>

# %%
text="Jewish forces overcome Arab militants."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
# Out:
# Jewish insurgents overcome Arab militants.<|end_of_text|>

# %%
text="The lyrics are about mankind's perceived idea of hell."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
# Out:
# the lyrics are about idea of hell<|end_of_text|>

# %%
text="Marriage is a holy union of individuals."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
# Out:
# Marriage is a legal union of individuals.<|end_of_text|>

# %%
s3_data_path_train="drive-download-20241009T011832Z-001/bias_train_full.csv"

response = s3.get_object(Bucket=bucket_name, Key=s3_data_path_train)
training_data = pd.read_csv(BytesIO(response['Body'].read()))

s3_data_path_val="drive-download-20241009T011832Z-001/bias_val_full.csv"

response = s3.get_object(Bucket=bucket_name, Key=s3_data_path_val)
validation_data = pd.read_csv(BytesIO(response['Body'].read()))

# %%
data_prompt = """Provide a revised version of the input text that removes any subjective bias and ensures neutrality, objectivity and an unbiased point of view.

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token
def formatting_prompt(examples):
    inputs       = examples["src_raw"]
    outputs      = examples["tgt_raw"]
    texts = []
    for input_, output in zip(inputs, outputs):
        text = data_prompt.format(input_, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# %%
train_data = Dataset.from_pandas(training_data)
train_data = train_data.map(formatting_prompt, batched=True)

val_data = Dataset.from_pandas(validation_data)
val_data = val_data.map(formatting_prompt, batched=True)
# Out:
# ...
# Map:   0%|          | 0/25665 [00:00<?, ? examples/s]

# %%
trainer=SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_data,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    packing=False,
    args=TrainingArguments(
        learning_rate=3e-5,
        lr_scheduler_type="linear",
        per_device_train_batch_size=16,
        gradient_accumulation_steps=8,
        num_train_epochs=5,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        warmup_steps=100,
        output_dir="output",
        seed=0,
    ),
)

trainer.train()
# Out:
# Map (num_proc=2):   0%|          | 0/119770 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 119,770 | Num Epochs = 5
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 8
# \        /    Total batch size = 128 | Total steps = 4,675
#  "-____-"     Number of trainable parameters = 11,272,192
#     <div>
#
#       <progress value='4675' max='4675' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4675/4675 4:21:30, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.880200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.002800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.025600</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
text="He started writing books revealing a vast world conspiracy."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
# Out:
# he wrote books revealing a vast world conspiracy.<|end_of_text|>

# %%
text="Jewish forces overcome Arab militants."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
# Out:
# jewish forces overcome arab militants.<|end_of_text|>

# %%
text="The lyrics are about mankind's perceived idea of hell."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
# Out:
# the lyrics are about mankind's idea of hell.<|end_of_text|>

# %%
text="Marriage is a holy union of individuals."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
# Out:
# marriage is a holy union of individuals.<|end_of_text|>

# %%
import os
os.environ["HF_TOKEN"] = "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"
model.push_to_hub("violetdavis/finetuned_llama3.2_bias", use_auth_token=os.getenv("HF_TOKEN"))
tokenizer.push_to_hub("violetdavis/finetuned_llama3.2_bias", use_auth_token=os.getenv("HF_TOKEN"))
# Out:
# README.md:   0%|          | 0.00/582 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/45.1M [00:00<?, ?B/s]
# Saved model to https://huggingface.co/violetdavis/finetuned_llama3.2_bias
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]

# %%
model.save_pretrained("model/1B_finetuned_llama3.2")
tokenizer.save_pretrained("model/1B_finetuned_llama3.2")

# %%
s3_data_path_train="drive-download-20241009T011832Z-001/bias_train_full.csv"

response = s3.get_object(Bucket=bucket_name, Key=s3_data_path_train)
training_data = pd.read_csv(BytesIO(response['Body'].read()))

s3_data_path_val="drive-download-20241009T011832Z-001/bias_val_full.csv"

response = s3.get_object(Bucket=bucket_name, Key=s3_data_path_val)
validation_data = pd.read_csv(BytesIO(response['Body'].read()))

# %%
data_prompt = """Provide a revised version of the input text that removes any subjective bias and ensures neutrality, objectivity and an unbiased point of view.

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token
def formatting_prompt(examples):
    inputs       = examples["src_raw"]
    outputs      = examples["tgt_raw"]
    texts = []
    for input_, output in zip(inputs, outputs):
        text = data_prompt.format(input_, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# %%
train_data = Dataset.from_pandas(training_data)
train_data = train_data.map(formatting_prompt, batched=True)

val_data = Dataset.from_pandas(validation_data)
val_data = val_data.map(formatting_prompt, batched=True)
# Out:
# ...
# Map:   0%|          | 0/25665 [00:00<?, ? examples/s]

# %%
trainer=SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_data,
    eval_dataset=val_data,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    packing=False,
    args=TrainingArguments(
        learning_rate=3e-4,
        lr_scheduler_type="linear",
        per_device_train_batch_size=16,
        gradient_accumulation_steps=8,
        num_train_epochs=5,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        warmup_steps=10,
        output_dir="output",
        seed=0,
    ),
)

trainer.train()
# Out:
# ...
# Map (num_proc=2):   0%|          | 0/25665 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 119,770 | Num Epochs = 5
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 8
# \        /    Total batch size = 128 | Total steps = 4,675
#  "-____-"     Number of trainable parameters = 11,272,192
#     <div>
#
#       <progress value='4675' max='4675' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4675/4675 6:16:54, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.686200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.670100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.611300</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
text="He started writing books revealing a vast world conspiracy."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
text="Jewish forces overcome Arab militants."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
text="The lyrics are about mankind's perceived idea of hell."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)

text="Marriage is a holy union of individuals."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
# Out:
# he started writing books alleging a vast world conspiracy.<|end_of_text|>
#
# jewish forces overcome arab militants.<|end_of_text|>
#
# the lyrics are about hell.<|end_of_text|>
#
# marriage is an union of individuals.<|end_of_text|>

# %%
import os
os.environ["HF_TOKEN"] = "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"
model.push_to_hub("violetdavis/finetuned_llama3.2_bias2", use_auth_token=os.getenv("HF_TOKEN"))
tokenizer.push_to_hub("violetdavis/finetuned_llama3.2_bias2", use_auth_token=os.getenv("HF_TOKEN"))
# Out:
# adapter_model.safetensors:   0%|          | 0.00/45.1M [00:00<?, ?B/s]
# Saved model to https://huggingface.co/violetdavis/finetuned_llama3.2_bias2
# No files have been modified since last commit. Skipping to prevent empty commit.

# %%
data_prompt = """Translate from biased to unbiased

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token
def formatting_prompt(examples):
    inputs       = examples["src_raw"]
    outputs      = examples["tgt_raw"]
    texts = []
    for input_, output in zip(inputs, outputs):
        text = data_prompt.format(input_, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# %%
train_data = Dataset.from_pandas(training_data)
train_data = train_data.map(formatting_prompt, batched=True)

val_data = Dataset.from_pandas(validation_data)
val_data = val_data.map(formatting_prompt, batched=True)
# Out:
# ...
# Map:   0%|          | 0/25665 [00:00<?, ? examples/s]

# %%
trainer=SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_data,
    eval_dataset=val_data,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    packing=False,
    args=TrainingArguments(
        learning_rate=3e-4,
        lr_scheduler_type="linear",
        per_device_train_batch_size=16,
        gradient_accumulation_steps=8,
        num_train_epochs=5,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        warmup_steps=10,
        output_dir="output",
        seed=0,
    ),
)

trainer.train()
# Out:
# Map (num_proc=2):   0%|          | 0/119770 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 trainer=SFTTrainer(
#       2     model=model,
#       3     tokenizer=tokenizer,
#       4     train_dataset=train_data,
#       5     eval_dataset=val_data,
#       6     dataset_text_field="text",
#       7     max_seq_length=max_seq_length,
#       8     dataset_num_proc=2,
#       9     packing=False,
#      10     args=TrainingArguments(
#      11         learning_rate=3e-4,
#      12         lr_scheduler_type="linear",
#      13         per_device_train_batch_size=16,
#      14         gradient_accumulation_steps=8,
#      15         num_train_epochs=5,
#      16         fp16=not is_bfloat16_supported(),
#      17         bf16=is_bfloat16_supported(),
#      18         logging_steps=1,
#      19         optim="adamw_8bit",
# ...

# %%
text="He started writing books revealing a vast world conspiracy."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
text="Jewish forces overcome Arab militants."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
text="The lyrics are about mankind's perceived idea of hell."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)

text="Marriage is a holy union of individuals."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)

# %%
import os
os.environ["HF_TOKEN"] = "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"
model.push_to_hub("violetdavis/finetuned_llama3.2_bias3", use_auth_token=os.getenv("HF_TOKEN"))
tokenizer.push_to_hub("violetdavis/finetuned_llama3.2_bias3", use_auth_token=os.getenv("HF_TOKEN"))

# %% [markdown]
# TESTING

# %%
s3_data_path_test="drive-download-20241009T011832Z-001/bias_test_med.csv"

response = s3.get_object(Bucket=bucket_name, Key=s3_data_path_test)
test_data = pd.read_csv(BytesIO(response['Body'].read()))

# %% [markdown]
# Test1

# %%
max_seq_length = 520
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="violetdavis/finetuned_llama3.2_bias",
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    dtype=None,
)
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
data_prompt = """Provide a revised version of the input text that removes any subjective bias and ensures neutrality, objectivity and an unbiased point of view.

### Input:
{}

### Response:
{}"""

# %%
len(test_data["src_raw"])
# Out:
# 7699

# %%
batch_size = 100  # Adjust this based on your GPU memory capacity
results = []

model = FastLanguageModel.for_inference(model)

# Process in batches
for i in range(0, len(test_data["src_raw"]), batch_size):
    batch_texts = test_data["src_raw"][i:i + batch_size]
    inputs = tokenizer(
        [data_prompt.format(text, "") for text in batch_texts], 
        return_tensors="pt", 
        padding=True, 
        truncation=True
    ).to("cuda")

    # Generate predictions
    outputs = model.generate(
        **inputs,
        max_new_tokens=520,
        use_cache=True
    )

    # Decode the outputs
    batch_answers = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    results.extend([answer.split("### Response:")[-1].strip() for answer in batch_answers])

# %%
df = pd.DataFrame(results)
df.to_csv("results1.csv", index=False)

# %% [markdown]
# Test2

# %%
max_seq_length = 520
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="violetdavis/finetuned_llama3.2_bias2",
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    dtype=None,
)
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# adapter_model.safetensors:   0%|          | 0.00/45.1M [00:00<?, ?B/s]

# %%
data_prompt = """Provide a revised version of the input text that removes any subjective bias and ensures neutrality, objectivity and an unbiased point of view.

### Input:
{}

### Response:
{}"""

# %%
batch_size = 100  # Adjust this based on your GPU memory capacity
results = []

model = FastLanguageModel.for_inference(model)

# Process in batches
for i in range(0, len(test_data["src_raw"]), batch_size):
    batch_texts = test_data["src_raw"][i:i + batch_size]
    inputs = tokenizer(
        [data_prompt.format(text, "") for text in batch_texts], 
        return_tensors="pt", 
        padding=True, 
        truncation=True
    ).to("cuda")

    # Generate predictions
    outputs = model.generate(
        **inputs,
        max_new_tokens=520,
        use_cache=True
    )

    # Decode the outputs
    batch_answers = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    results.extend([answer.split("### Response:")[-1].strip() for answer in batch_answers])

# %%
df = pd.DataFrame(results)
df.to_csv("results2.csv", index=False)

# %% [markdown]
# Test3

# %%
max_seq_length = 520
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="violetdavis/finetuned_llama3.2_bias3",
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    dtype=None,
)
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# adapter_model.safetensors:   0%|          | 0.00/45.1M [00:00<?, ?B/s]

# %%
data_prompt = """Translate from biased to unbiased

### Input:
{}

### Response:
{}"""

# %%
batch_size = 100  # Adjust this based on your GPU memory capacity
results = []

model = FastLanguageModel.for_inference(model)

# Process in batches
for i in range(0, len(test_data["src_raw"]), batch_size):
    batch_texts = test_data["src_raw"][i:i + batch_size]
    inputs = tokenizer(
        [data_prompt.format(text, "") for text in batch_texts], 
        return_tensors="pt", 
        padding=True, 
        truncation=True
    ).to("cuda")

    # Generate predictions
    outputs = model.generate(
        **inputs,
        max_new_tokens=520,
        use_cache=True
    )

    # Decode the outputs
    batch_answers = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    results.extend([answer.split("### Response:")[-1].strip() for answer in batch_answers])

# %%
df = pd.DataFrame(results)
df.to_csv("results3.csv", index=False)

# %%
text="He started writing books revealing a vast world conspiracy."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1].strip()
print(answer)
text="Jewish forces overcome Arab militants."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
text="The lyrics are about mankind's perceived idea of hell."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)

text="Marriage is a holy union of individuals."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
text="A lead programmer usually spends his career mired in obscurity."
model = FastLanguageModel.for_inference(model)
inputs = tokenizer(
[
    data_prompt.format(
        #instructions
        text,
        #answer
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 520, use_cache = True)
answer=tokenizer.batch_decode(outputs)
answer = answer[0].split("### Response:")[-1]
print(answer)
# Out:
# he started writing books revealing a conspiracy.<|end_of_text|>
#
# jewish forces overcome arab forces.<|end_of_text|>
#
# the lyrics are about mankind's perceived idea of hell.<|end_of_text|>
#
# marriage is a union of individuals.<|end_of_text|>
#
# a lead programmer usually spends his career working low down the ladder mired in obscurity.<|end_of_text|>
